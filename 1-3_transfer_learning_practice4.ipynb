# %% [markdown]
# # 1.3「転移学習」で少量データの分類を実現する方法
#
# - 本ファイルでは、学習済みのVGGモデルを使用し、転移学習でアリとハチの画像を分類するモデルを学習します

# %% [markdown]
# # 学習目標
#
# 1. 画像データからDatasetを作成できるようになる
# 2. DataSetからDataLoaderを作成できるようになる
# 3. 学習済みモデルの出力層を任意の形に変更できるようになる
# 4. 出力層の結合パラメータのみを学習させ、転移学習が実装できるようになる

# %% [markdown]
# # 事前準備
#
# 1. 書籍の指示に従い、本章で使用するデータをダウンロード
#
# 2. forループの経過時間と残り時間を計測するパッケージtqdmをインストールします。
#
# conda install -c conda-forge tqdm

# %%
# パッケージのimport
import glob
import os.path as osp
import random
import numpy as np
import json
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torchvision
from torchvision import models, transforms

# %%
# 乱数のシードを設定
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # DataSetを作成

# %%
# 入力画像の前処理をするクラス
# 訓練時と推論時で処理が異なる


class ImageTransform():
    """
    画像の前処理クラス。訓練時、検証時で異なる動作をする。
    画像のサイズをリサイズし、色を標準化する。
    訓練時はRandomResizedCropとRandomHorizontalFlipでデータオーギュメンテーションする。


    Attributes
    ----------
    resize : int
        リサイズ先の画像の大きさ。
    mean : (R, G, B)
        各色チャネルの平均値。
    std : (R, G, B)
        各色チャネルの標準偏差。
    """

    def __init__(self, resize, mean, std):
        self.data_transform = {
            'train': transforms.Compose([
                transforms.RandomResizedCrop(
                    resize, scale=(0.5, 1.0)),  # データオーギュメンテーション
                transforms.RandomHorizontalFlip(),  # データオーギュメンテーション
                transforms.ToTensor(),  # テンソルに変換
                transforms.Normalize(mean, std)  # 標準化
            ]),
            'val': transforms.Compose([
                transforms.Resize(resize),  # リサイズ
                transforms.CenterCrop(resize),  # 画像中央をresize×resizeで切り取り
                transforms.ToTensor(),  # テンソルに変換
                transforms.Normalize(mean, std)  # 標準化
            ])
        }

    def __call__(self, img, phase='train'):
        """
        Parameters
        ----------
        phase : 'train' or 'val'
            前処理のモードを指定。
        """
        return self.data_transform[phase](img)

# %%
# 訓練時の画像前処理の動作を確認
# 実行するたびに処理結果の画像が変わる

# 1. 画像読み込み
image_file_path = './data/sea_day121.jpg'
img = Image.open(image_file_path)   # [高さ][幅][色RGB]

# 2. 元の画像の表示
plt.imshow(img)
plt.show()

# 3. 画像の前処理と処理済み画像の表示
size = 224
mean = (0.485, 0.456, 0.406)
std = (0.229, 0.224, 0.225)

transform = ImageTransform(size, mean, std)
img_transformed = transform(img, phase="train")  # torch.Size([3, 224, 224])

# (色、高さ、幅)を (高さ、幅、色)に変換し、0-1に値を制限して表示
img_transformed = img_transformed.numpy().transpose((1, 2, 0))
img_transformed = np.clip(img_transformed, 0, 1)
plt.imshow(img_transformed)
plt.show()

# %%
# アリとハチの画像へのファイルパスのリストを作成する


def make_datapath_list(phase="train"):
    """
    データのパスを格納したリストを作成する。

    Parameters
    ----------
    phase : 'train' or 'val'
        訓練データか検証データかを指定する

    Returns
    -------
    path_list : list
        データへのパスを格納したリスト
    """

    rootpath = "./data/jk/"
    target_path = osp.join(rootpath+phase+'/**/*.jpg')
    print(target_path)

    path_list = []  # ここに格納する

    # globを利用してサブディレクトリまでファイルパスを取得する
    for path in glob.glob(target_path):
        path_list.append(path)

    return path_list


# 実行

train_list = make_datapath_list(phase="train")
val_list = make_datapath_list(phase="val")

train_list
# Out:
# ./data/jk/train/**/*.jpg
# ./data/jk/val/**/*.jpg
# ['./data/jk/train\\bld\\bld_day1015.jpg',
#  './data/jk/train\\bld\\bld_day1472.jpg',
#  './data/jk/train\\bld\\bld_day1697.jpg',
#  './data/jk/train\\bld\\bld_day1700.jpg',
#  './data/jk/train\\bld\\bld_day1733.jpg',
#  './data/jk/train\\bld\\bld_day17842597133459133.jpg',
#  './data/jk/train\\bld\\bld_day17842631702455770.jpg',
#  './data/jk/train\\bld\\bld_day17843567192424048.jpg',
#  './data/jk/train\\bld\\bld_day17843798798445317.jpg',
#  './data/jk/train\\bld\\bld_day17846791802363717.jpg',
#  './data/jk/train\\bld\\bld_day17854738493252260.jpg',
#  './data/jk/train\\bld\\bld_day17854931669304256.jpg',
#  './data/jk/train\\bld\\bld_day17855082668297778.jpg',
#  './data/jk/train\\bld\\bld_day17859080417172190.jpg',
#  './data/jk/train\\bld\\bld_day17862143021162234.jpg',
#  './data/jk/train\\bld\\bld_day17864110904080985.jpg',
#  './data/jk/train\\bld\\bld_day17868095405069095.jpg',
#  './data/jk/train\\bld\\bld_day17869077647016472.jpg',
#  './data/jk/train\\bld\\bld_day17869815623049134.jpg',
#  './data/jk/train\\bld\\bld_day17870009480030027.jpg',
#  './data/jk/train\\bld\\bld_day17870157532998805.jpg',
#  './data/jk/train\\bld\\bld_day17870811308013006.jpg',
#  './data/jk/train\\bld\\bld_day17871101281982858.jpg',
#  './data/jk/train\\bld\\bld_day17871386665975846.jpg',
#  './data/jk/train\\bld\\bld_day17875964098912255.jpg',
#  './data/jk/train\\bld\\bld_day17882034745791627.jpg',
#  './data/jk/train\\bld\\bld_day17889763762699398.jpg',
#  './data/jk/train\\bld\\bld_day17889770458694034.jpg',
#  './data/jk/train\\bld\\bld_day17892644689657045.jpg',
#  './data/jk/train\\bld\\bld_day17929046005438132.jpg',
#  './data/jk/train\\bld\\bld_day17931863362426292.jpg',
#  './data/jk/train\\bld\\bld_day17962852108349401.jpg',
#  './data/jk/train\\bld\\bld_day17977469728317037.jpg',
#  './data/jk/train\\bld\\bld_day17981043025311399.jpg',
#  './data/jk/train\\bld\\bld_day18031498867302834.jpg',
#  './data/jk/train\\bld\\bld_day18032157406281532.jpg',
#  './data/jk/train\\bld\\bld_day18073868608239601.jpg',
#  './data/jk/train\\bld\\bld_day18074958082226099.jpg',
#  './data/jk/train\\bld\\bld_day18079758190217979.jpg',
#  './data/jk/train\\bld\\bld_day18087676810206064.jpg',
#  './data/jk/train\\bld\\bld_day18105110848173617.jpg',
#  './data/jk/train\\bld\\bld_day18126423982137015.jpg',
#  './data/jk/train\\bld\\bld_day18166509847063511.jpg',
#  './data/jk/train\\bld\\bld_day18167921323008031.jpg',
#  './data/jk/train\\bld\\bld_day212.jpg',
#  './data/jk/train\\bld\\bld_day298.jpg',
#  './data/jk/train\\bld\\bld_day316.jpg',
#  './data/jk/train\\bld\\bld_day437.jpg',
#  './data/jk/train\\bld\\bld_day438.jpg',
#  './data/jk/train\\bld\\bld_day585.jpg',
#  './data/jk/train\\bld\\bld_day675.jpg',
#  './data/jk/train\\bld\\bld_day697.jpg',
#  './data/jk/train\\bld\\bld_day725.jpg',
#  './data/jk/train\\bld\\bld_day821.jpg',
#  './data/jk/train\\bld\\bld_day87.jpg',
#  './data/jk/train\\bld\\bld_day883.jpg',
#  './data/jk/train\\bld\\bld_day885.jpg',
#  './data/jk/train\\bld\\bld_nit1012.jpg',
#  './data/jk/train\\bld\\bld_nit1013.jpg',
#  './data/jk/train\\bld\\bld_nit1025.jpg',
#  './data/jk/train\\bld\\bld_nit1030.jpg',
#  './data/jk/train\\bld\\bld_nit1085.jpg',
#  './data/jk/train\\bld\\bld_nit1086.jpg',
#  './data/jk/train\\bld\\bld_nit1119.jpg',
#  './data/jk/train\\bld\\bld_nit1170.jpg',
#  './data/jk/train\\bld\\bld_nit1183.jpg',
#  './data/jk/train\\bld\\bld_nit1191.jpg',
#  './data/jk/train\\bld\\bld_nit1193.jpg',
#  './data/jk/train\\bld\\bld_nit1197.jpg',
#  './data/jk/train\\bld\\bld_nit1199.jpg',
#  './data/jk/train\\bld\\bld_nit1238.jpg',
#  './data/jk/train\\bld\\bld_nit1263.jpg',
#  './data/jk/train\\bld\\bld_nit1362.jpg',
#  './data/jk/train\\bld\\bld_nit1363.jpg',
#  './data/jk/train\\bld\\bld_nit1364.jpg',
#  './data/jk/train\\bld\\bld_nit1365.jpg',
#  './data/jk/train\\bld\\bld_nit1408.jpg',
#  './data/jk/train\\bld\\bld_nit1412.jpg',
#  './data/jk/train\\bld\\bld_nit1470.jpg',
#  './data/jk/train\\bld\\bld_nit1480.jpg',
#  './data/jk/train\\bld\\bld_nit1483.jpg',
#  './data/jk/train\\bld\\bld_nit1566.jpg',
#  './data/jk/train\\bld\\bld_nit1691.jpg',
#  './data/jk/train\\bld\\bld_nit174.jpg',
#  './data/jk/train\\bld\\bld_nit178.jpg',
#  './data/jk/train\\bld\\bld_nit17843703494442495.jpg',
#  './data/jk/train\\bld\\bld_nit17869203725044106.jpg',
#  './data/jk/train\\bld\\bld_nit17879601796872897.jpg',
#  './data/jk/train\\bld\\bld_nit17881550002813471.jpg',
#  './data/jk/train\\bld\\bld_nit17888161885705830.jpg',
#  './data/jk/train\\bld\\bld_nit17890078261677281.jpg',
#  './data/jk/train\\bld\\bld_nit17891999674668470.jpg',
#  './data/jk/train\\bld\\bld_nit17980191487314119.jpg',
#  './data/jk/train\\bld\\bld_nit1812.jpg',
#  './data/jk/train\\bld\\bld_nit1816.jpg',
#  './data/jk/train\\bld\\bld_nit18168698995040466.jpg',
#  './data/jk/train\\bld\\bld_nit182.jpg',
#  './data/jk/train\\bld\\bld_nit1886.jpg',
#  './data/jk/train\\bld\\bld_nit194.jpg',
#  './data/jk/train\\bld\\bld_nit238.jpg',
#  './data/jk/train\\bld\\bld_nit292.jpg',
#  './data/jk/train\\bld\\bld_nit294.jpg',
#  './data/jk/train\\bld\\bld_nit296.jpg',
#  './data/jk/train\\bld\\bld_nit313.jpg',
#  './data/jk/train\\bld\\bld_nit317.jpg',
#  './data/jk/train\\bld\\bld_nit360.jpg',
#  './data/jk/train\\bld\\bld_nit370.jpg',
#  './data/jk/train\\bld\\bld_nit373.jpg',
#  './data/jk/train\\bld\\bld_nit38.jpg',
#  './data/jk/train\\bld\\bld_nit390.jpg',
#  './data/jk/train\\bld\\bld_nit391.jpg',
#  './data/jk/train\\bld\\bld_nit404.jpg',
#  './data/jk/train\\bld\\bld_nit405.jpg',
#  './data/jk/train\\bld\\bld_nit407.jpg',
#  './data/jk/train\\bld\\bld_nit418.jpg',
#  './data/jk/train\\bld\\bld_nit421.jpg',
#  './data/jk/train\\bld\\bld_nit422.jpg',
#  './data/jk/train\\bld\\bld_nit425.jpg',
#  './data/jk/train\\bld\\bld_nit426.jpg',
#  './data/jk/train\\bld\\bld_nit427.jpg',
#  './data/jk/train\\bld\\bld_nit471.jpg',
#  './data/jk/train\\bld\\bld_nit491.jpg',
#  './data/jk/train\\bld\\bld_nit492.jpg',
#  './data/jk/train\\bld\\bld_nit520.jpg',
#  './data/jk/train\\bld\\bld_nit522.jpg',
#  './data/jk/train\\bld\\bld_nit538.jpg',
#  './data/jk/train\\bld\\bld_nit568.jpg',
#  './data/jk/train\\bld\\bld_nit658.jpg',
#  './data/jk/train\\bld\\bld_nit662.jpg',
#  './data/jk/train\\bld\\bld_nit72.jpg',
#  './data/jk/train\\bld\\bld_nit735.jpg',
#  './data/jk/train\\bld\\bld_nit737.jpg',
#  './data/jk/train\\bld\\bld_nit740.jpg',
#  './data/jk/train\\bld\\bld_nit741.jpg',
#  './data/jk/train\\bld\\bld_nit742.jpg',
#  './data/jk/train\\bld\\bld_nit743.jpg',
#  './data/jk/train\\bld\\bld_nit886.jpg',
#  './data/jk/train\\bld\\bld_nit894.jpg',
#  './data/jk/train\\bld\\bld_nit900.jpg',
#  './data/jk/train\\bld\\bld_nit91.jpg',
#  './data/jk/train\\bld\\bld_nit928.jpg',
#  './data/jk/train\\bld\\bld_nit978.jpg',
#  './data/jk/train\\bld\\bld_nit983.jpg',
#  './data/jk/train\\bld\\bld_nit985.jpg',
#  './data/jk/train\\bld\\bld_nit989.jpg',
#  './data/jk/train\\bld\\bld_sns1010.jpg',
#  './data/jk/train\\bld\\bld_sns1014.jpg',
#  './data/jk/train\\bld\\bld_sns1017.jpg',
#  './data/jk/train\\bld\\bld_sns1019.jpg',
#  './data/jk/train\\bld\\bld_sns1022.jpg',
#  './data/jk/train\\bld\\bld_sns1024.jpg',
#  './data/jk/train\\bld\\bld_sns1083.jpg',
#  './data/jk/train\\bld\\bld_sns1104.jpg',
#  './data/jk/train\\bld\\bld_sns1184.jpg',
#  './data/jk/train\\bld\\bld_sns1196.jpg',
#  './data/jk/train\\bld\\bld_sns1235.jpg',
#  './data/jk/train\\bld\\bld_sns1239.jpg',
#  './data/jk/train\\bld\\bld_sns1310.jpg',
#  './data/jk/train\\bld\\bld_sns1423.jpg',
#  './data/jk/train\\bld\\bld_sns1493.jpg',
#  './data/jk/train\\bld\\bld_sns17870642900013796.jpg',
#  './data/jk/train\\bld\\bld_sns17870780054016151.jpg',
#  './data/jk/train\\bld\\bld_sns17889729646697765.jpg',
#  './data/jk/train\\bld\\bld_sns17969534968333127.jpg',
#  './data/jk/train\\bld\\bld_sns18088320628202644.jpg',
#  './data/jk/train\\bld\\bld_sns18104904526175459.jpg',
#  './data/jk/train\\bld\\bld_sns18130752100126584.jpg',
#  './data/jk/train\\bld\\bld_sns18166776499028643.jpg',
#  './data/jk/train\\bld\\bld_sns208.jpg',
#  './data/jk/train\\bld\\bld_sns312.jpg',
#  './data/jk/train\\bld\\bld_sns314.jpg',
#  './data/jk/train\\bld\\bld_sns335.jpg',
#  './data/jk/train\\bld\\bld_sns345.jpg',
#  './data/jk/train\\bld\\bld_sns354.jpg',
#  './data/jk/train\\bld\\bld_sns369.jpg',
#  './data/jk/train\\bld\\bld_sns372.jpg',
#  './data/jk/train\\bld\\bld_sns393.jpg',
#  './data/jk/train\\bld\\bld_sns440.jpg',
#  './data/jk/train\\bld\\bld_sns499.jpg',
#  './data/jk/train\\bld\\bld_sns521.jpg',
#  './data/jk/train\\bld\\bld_sns535.jpg',
#  './data/jk/train\\bld\\bld_sns808.jpg',
#  './data/jk/train\\bld\\bld_sns888.jpg',
#  './data/jk/train\\bld\\bld_sns893.jpg',
#  './data/jk/train\\bld\\bld_sns982.jpg',
#  './data/jk/train\\bld\\bld_sns991.jpg',
#  './data/jk/train\\bld\\bld_sns992.jpg',
#  './data/jk/train\\mnt\\mnt_day1208.jpg',
#  './data/jk/train\\mnt\\mnt_day1212.jpg',
#  './data/jk/train\\mnt\\mnt_day1220.jpg',
#  './data/jk/train\\mnt\\mnt_day1380.jpg',
#  './data/jk/train\\mnt\\mnt_day1382.jpg',
#  './data/jk/train\\mnt\\mnt_day1387.jpg',
#  './data/jk/train\\mnt\\mnt_day1389.jpg',
#  './data/jk/train\\mnt\\mnt_day1474.jpg',
#  './data/jk/train\\mnt\\mnt_day1506.jpg',
#  './data/jk/train\\mnt\\mnt_day1609.jpg',
#  './data/jk/train\\mnt\\mnt_day1624.jpg',
#  './data/jk/train\\mnt\\mnt_day1640.jpg',
#  './data/jk/train\\mnt\\mnt_day172.jpg',
#  './data/jk/train\\mnt\\mnt_day175.jpg',
#  './data/jk/train\\mnt\\mnt_day17842764041438343.jpg',
#  './data/jk/train\\mnt\\mnt_day17845088516402661.jpg',
#  './data/jk/train\\mnt\\mnt_day17845278962409109.jpg',
#  './data/jk/train\\mnt\\mnt_day17847443591377371.jpg',
#  './data/jk/train\\mnt\\mnt_day17852650667303417.jpg',
#  './data/jk/train\\mnt\\mnt_day17853683621274243.jpg',
#  './data/jk/train\\mnt\\mnt_day17853940517277152.jpg',
#  './data/jk/train\\mnt\\mnt_day17854007846278897.jpg',
#  './data/jk/train\\mnt\\mnt_day17854420913262076.jpg',
#  './data/jk/train\\sky\\sky_sns17875887928911496.jpg',
#  './data/jk/train\\sky\\sky_sns17878461676866172.jpg',
#  './data/jk/train\\sky\\sky_sns17879244460879197.jpg',
#  './data/jk/train\\sky\\sky_sns17882097556795634.jpg',
#  './data/jk/train\\sky\\sky_sns17885732827751996.jpg',
#  './data/jk/train\\sky\\sky_sns17891871028667093.jpg',
#  './data/jk/train\\sky\\sky_sns17893339255649770.jpg',
#  './data/jk/train\\sky\\sky_sns17896201042621999.jpg',
#  './data/jk/train\\sky\\sky_sns17896220689617445.jpg',
#  './data/jk/train\\sky\\sky_sns17897363284609274.jpg',
#  './data/jk/train\\sky\\sky_sns17898976750600068.jpg',
#  './data/jk/train\\sky\\sky_sns17905894225544881.jpg',
#  './data/jk/train\\sky\\sky_sns17912028550486585.jpg',
#  './data/jk/train\\sky\\sky_sns17918266789468801.jpg',
#  './data/jk/train\\sky\\sky_sns17935298563412838.jpg',
#  './data/jk/train\\sky\\sky_sns17944496875387919.jpg',
#  './data/jk/train\\sky\\sky_sns17944822057391448.jpg',
#  './data/jk/train\\sky\\sky_sns17950559119372649.jpg',
#  './data/jk/train\\sky\\sky_sns17954788858365411.jpg',
#  './data/jk/train\\sky\\sky_sns17969918704329239.jpg',
#  './data/jk/train\\sky\\sky_sns17974121233325501.jpg',
#  './data/jk/train\\sky\\sky_sns18027586252305181.jpg',
#  './data/jk/train\\sky\\sky_sns18049164070270101.jpg',
#  './data/jk/train\\sky\\sky_sns18113841685160519.jpg',
#  './data/jk/train\\sky\\sky_sns18129356224120696.jpg',
#  './data/jk/train\\sky\\sky_sns18129480085126503.jpg',
#  './data/jk/train\\sky\\sky_sns18138146554099789.jpg',
#  './data/jk/train\\sky\\sky_sns18138167011107779.jpg',
#  './data/jk/train\\sky\\sky_sns18150262009075327.jpg',
#  './data/jk/train\\sky\\sky_sns18166896673049988.jpg',
#  './data/jk/train\\sky\\sky_sns18169895677044157.jpg',
#  './data/jk/train\\sky\\sky_sns185.jpg',
#  './data/jk/train\\sky\\sky_sns189.jpg',
#  './data/jk/train\\sky\\sky_sns190.jpg',
#  './data/jk/train\\sky\\sky_sns192.jpg',
#  './data/jk/train\\sky\\sky_sns195.jpg',
#  './data/jk/train\\sky\\sky_sns225.jpg',
#  './data/jk/train\\sky\\sky_sns254.jpg',
#  './data/jk/train\\sky\\sky_sns280.jpg',
#  './data/jk/train\\sky\\sky_sns305.jpg',
#  './data/jk/train\\sky\\sky_sns339.jpg',
#  './data/jk/train\\sky\\sky_sns44.jpg',
#  './data/jk/train\\sky\\sky_sns53.jpg',
#  './data/jk/train\\sky\\sky_sns548.jpg',
#  './data/jk/train\\sky\\sky_sns566.jpg',
#  './data/jk/train\\sky\\sky_sns6.jpg',
#  './data/jk/train\\sky\\sky_sns645.jpg',
#  './data/jk/train\\sky\\sky_sns647.jpg',
#  './data/jk/train\\sky\\sky_sns97.jpg']

# %%
print(len(train_list))
print(len(val_list))
# Out:
# 689
# 169

# %%
# アリとハチの画像のDatasetを作成する


class HymenopteraDataset(data.Dataset):
    """
    アリとハチの画像のDatasetクラス。PyTorchのDatasetクラスを継承。

    Attributes
    ----------
    file_list : リスト
        画像のパスを格納したリスト
    transform : object
        前処理クラスのインスタンス
    phase : 'train' or 'test'
        学習か訓練かを設定する。
    """

    def __init__(self, file_list, transform=None, phase='train'):
        self.file_list = file_list  # ファイルパスのリスト
        self.transform = transform  # 前処理クラスのインスタンス
        self.phase = phase  # train or valの指定

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''
        前処理をした画像のTensor形式のデータとラベルを取得
        '''

        # index番目の画像をロード
        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅][色RGB]

        # 画像の前処理を実施
        img_transformed = self.transform(
            img, self.phase)  # torch.Size([3, 224, 224])

        # 画像のラベルをファイル名から抜き出す
        if self.phase == "train":
            label = img_path[16:19]
        elif self.phase == "val":
            label = img_path[14:17]

        # ラベルを数値に変更する
        if label == "bld":
            label = 0
        elif label == "mnt":
            label = 1
        elif label == "sky":
            label = 2
        elif label == "sea":
            label = 3
        return img_transformed, label


# 実行
train_dataset = HymenopteraDataset(
    file_list=train_list, transform=ImageTransform(size, mean, std), phase='train')

val_dataset = HymenopteraDataset(
    file_list=val_list, transform=ImageTransform(size, mean, std), phase='val')

# 動作確認
index = 0
print(train_dataset.__getitem__(index)[0].size())
print(train_dataset.__getitem__(index)[1])
# Out:
# torch.Size([3, 224, 224])
# 0

# %% [markdown]
# # DataLoaderを作成

# %%
# ミニバッチのサイズを指定
batch_size = 32

# DataLoaderを作成
train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

val_dataloader = torch.utils.data.DataLoader(
    val_dataset, batch_size=batch_size, shuffle=False)

# 辞書型変数にまとめる
dataloaders_dict = {"train": train_dataloader, "val": val_dataloader}

# 動作確認
batch_iterator = iter(dataloaders_dict["train"])  # イテレータに変換
inputs, labels = next(
    batch_iterator)  # 1番目の要素を取り出す
print(inputs.size())
print(labels)
# Out:
# torch.Size([32, 3, 224, 224])
# tensor([2, 2, 2, 2, 1, 2, 3, 1, 1, 0, 0, 0, 0, 2, 3, 2, 1, 3, 0, 0, 1, 2, 3, 1,
#         3, 0, 2, 3, 3, 1, 1, 2])

# %% [markdown]
# # ネットワークモデルの作成する

# %%
# 学習済みのVGG-16モデルをロード
# VGG-16モデルのインスタンスを生成
use_pretrained = True  # 学習済みのパラメータを使用
net = models.vgg16(pretrained=use_pretrained)

# VGG16の最後の出力層の出力ユニットをアリとハチの2つに付け替える
net.classifier[6] = nn.Linear(in_features=4096, out_features=4)

# 訓練モードに設定
net.train()

print('ネットワーク設定完了：学習済みの重みをロードし、訓練モードに設定しました')
# Out:
# ネットワーク設定完了：学習済みの重みをロードし、訓練モードに設定しました

# %% [markdown]
# # 損失関数を定義

# %%
# 損失関数の設定
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# # 最適化手法を設定

# %%
# 転移学習で学習させるパラメータを、変数params_to_updateに格納する
params_to_update = []

# 学習させるパラメータ名
update_param_names = ["classifier.6.weight", "classifier.6.bias"]

# 学習させるパラメータ以外は勾配計算をなくし、変化しないように設定
for name, param in net.named_parameters():
    if name in update_param_names:
        param.requires_grad = True
        params_to_update.append(param)
        print(name)
    else:
        param.requires_grad = False

# params_to_updateの中身を確認
print("-----------")
print(params_to_update)
# Out:
# classifier.6.weight
# classifier.6.bias
# -----------
# [Parameter containing:
# tensor([[-0.0052, -0.0063,  0.0049,  ...,  0.0096, -0.0047,  0.0089],
#         [-0.0001,  0.0103, -0.0100,  ..., -0.0024, -0.0060,  0.0101],
#         [ 0.0044,  0.0099,  0.0021,  ..., -0.0028,  0.0133,  0.0011],
#         [-0.0042,  0.0038,  0.0153,  ...,  0.0083,  0.0151,  0.0133]],
#        requires_grad=True), Parameter containing:
# tensor([-0.0052, -0.0016, -0.0132, -0.0017], requires_grad=True)]

# %%
# 最適化手法の設定
optimizer = optim.SGD(params=params_to_update, lr=0.001, momentum=0.9)

# %% [markdown]
# # 学習・検証を実施

# %%
# モデルを学習させる関数を作成


def train_model(net, dataloaders_dict, criterion, optimizer, num_epochs):

    # epochのループ
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-------------')

        # epochごとの学習と検証のループ
        for phase in ['train', 'val']:
            if phase == 'train':
                net.train()  # モデルを訓練モードに
            else:
                net.eval()   # モデルを検証モードに

            epoch_loss = 0.0  # epochの損失和
            epoch_corrects = 0  # epochの正解数

            # 未学習時の検証性能を確かめるため、epoch=0の訓練は省略
            if (epoch == 0) and (phase == 'train'):
                continue

            # データローダーからミニバッチを取り出すループ
            for inputs, labels in tqdm(dataloaders_dict[phase]):

                # optimizerを初期化
                optimizer.zero_grad()

                # 順伝搬（forward）計算
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = net(inputs)
                    loss = criterion(outputs, labels)  # 損失を計算
                    _, preds = torch.max(outputs, 1)  # ラベルを予測
                    
  
                    # 訓練時はバックプロパゲーション
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                    # イタレーション結果の計算
                    # lossの合計を更新
                    epoch_loss += loss.item() * inputs.size(0)  
                    # 正解数の合計を更新
                    epoch_corrects += torch.sum(preds == labels.data)

            # epochごとのlossと正解率を表示
            epoch_loss = epoch_loss / len(dataloaders_dict[phase].dataset)
            epoch_acc = epoch_corrects.double(
            ) / len(dataloaders_dict[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

# %%
# 学習・検証を実行する
num_epochs=3
train_model(net, dataloaders_dict, criterion, optimizer, num_epochs=num_epochs)
# Out:
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
# Epoch 1/3
# -------------
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:15<00:00,  2.57s/it]
#   0%|                                                                                           | 0/22 [00:00<?, ?it/s]
# val Loss: 0.4449 Acc: 0.9053
# Epoch 2/3
# -------------
# 100%|██████████████████████████████████████████████████████████████████████████████████| 22/22 [01:06<00:00,  3.04s/it]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
# train Loss: 0.3909 Acc: 0.8737
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:16<00:00,  2.76s/it]
#   0%|                                                                                           | 0/22 [00:00<?, ?it/s]
# val Loss: 0.3110 Acc: 0.9231
# Epoch 3/3
# -------------
# 100%|██████████████████████████████████████████████████████████████████████████████████| 22/22 [01:08<00:00,  3.11s/it]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
# train Loss: 0.3190 Acc: 0.8897
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:16<00:00,  2.80s/it]
# val Loss: 0.2804 Acc: 0.9112

# %% [markdown]
# 以上
